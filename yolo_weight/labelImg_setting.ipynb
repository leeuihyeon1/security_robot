# %% [markdown]
# #labelImg용 데이터

# %% [markdown]
# - https://drive.google.com/file/d/1zYNiTuTFBF4YA40_vgYGmH6hG5maw7U5/view?usp=drive_link

# %% [markdown]
# #labelImg 설치

# %%
#%cd ~
# %cd ../content
# Out:
# /content

# %%
# !pwd
# Out:
# /root

# %%
# !git clone https://github.com/HumanSignal/labelImg.git
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2097 (delta 0), reused 5 (delta 0), pack-reused 2090 (from 1)
# Receiving objects: 100% (2097/2097), 237.14 MiB | 23.75 MiB/s, done.
# Resolving deltas: 100% (1245/1245), done.

# %%
# !sudo apt-get install pyqt5-dev-tools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libevdev2 libgudev-1.0-0 libinput-bin libinput10 libmd4c0 libmtdev1
#   libqt5core5a libqt5dbus5 libqt5designer5 libqt5gui5 libqt5help5
#   libqt5network5 libqt5printsupport5 libqt5sql5 libqt5sql5-sqlite libqt5svg5
#   libqt5test5 libqt5widgets5 libqt5xml5 libwacom-bin libwacom-common libwacom9
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 python3-pyqt5
#   python3-pyqt5.sip qt5-gtk-platformtheme qttranslations5-l10n
# Suggested packages:
#   qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   libevdev2 libgudev-1.0-0 libinput-bin libinput10 libmd4c0 libmtdev1
#   libqt5core5a libqt5dbus5 libqt5designer5 libqt5gui5 libqt5help5
# ...

# %%
# %cd labelImg
# Out:
# /content/labelImg

# %%
# !sudo pip3 install -r requirements/requirements-linux-python3.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyqt5
#     Found existing installation: PyQt5 5.15.11
#     Uninstalling PyQt5-5.15.11:
#       Successfully uninstalled PyQt5-5.15.11
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.4
#     Uninstalling lxml-4.9.4:
#       Successfully uninstalled lxml-4.9.4
# ...

# %%
# !make qt5py3
# Out:
# pyrcc5 -o libs/resources.py resources.qrc

# %%
# !python labelImg.py
# Out:
# /content/labelImg/labelImg.py:73: DeprecationWarning: sipPyTypeDict() is deprecated, the extension module should use sipPyTypeDictRef() instead
#   class MainWindow(QMainWindow, WindowMixin):
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #이미지 폴더의 위치를 정한다.

# %% [markdown]
# - 이미지와 라벨이 같은 경로에 생성됨(Change Save Dir)
#
# - 라벨의 저장 형식을 결정한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 이미지가 저장된 디렉토리를 선택하면 이미지 전체가 로딩된다.(Open Dir)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #class의 종류와 번호를 일치시키는 작업을 진행한다.

# %% [markdown]
# - truck 0, bus 1, tank 2 순으로 먼저 bounding box를 그린다.

# %% [markdown]
# - w를 누르면 bounding box 모드로 전환되고 클릭 후 드래그로 범위를 정한다.
#   - truck를 입력한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - w를 누르면 bounding box 모드로 전환되고 클릭 후 드래그로 범위를 정한다.
#   - bus를 입력한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - w를 누르면 bounding box 모드로 전환되고 클릭 후 드래그로 범위를 정한다.
#   - tank를 입력한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - classes.txt와 해당 이미지와 동일한 이름의 .txt 파일이 생성됨

# %% [markdown]
# # label을 지운다.

# %% [markdown]
# - bounding box를 선택하고 del 키로 지운다.

# %% [markdown]
# # label 작업을 진행한다.

# %% [markdown]
# 정식으로 라벨 작업을 진행한다.
#
# - w : 라벨 모드
#
#   - 클릭 후 드래그 : 바운딩 박스 작업
#
# - Ctrl + s : 저장
#
# - a : 이전 파일로 이동
#
# - d : 다음 파일로 이동

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install labelimg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 19.6 MB/s eta 0:00:00
# ...
#   Created wheel for labelimg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261520 sha256=92f357034d6ca2cb1f11b2e2927b74becdad9cbfe9841fe987c33b2a4a5a0a0a
#   Stored in directory: /root/.cache/pip/wheels/d9/f0/1e/74c509495458cad13a0fda23fe605e643177625cf2b5c17b34
# Successfully built labelimg
# ...

# %% [markdown]
# - https://kysf.tistory.com/18

# %% [markdown]
# # 아나콘다에서 실행

# %% [markdown]
# ## 설치

# %% [markdown]
# (base) C:\Users\HP>pip install labelImg
#
#
# ```
# Requirement already satisfied: labelImg in c:\users\hp\anaconda3\lib\site-packages (1.8.6)
#
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\lib\site-packages (from labelImg) (4.6.3)
#
# Requirement already satisfied: pyqt5 in c:\users\hp\anaconda3\lib\site-packages (from labelImg) (5.15.6)
#
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\hp\anaconda3\lib\site-packages (from pyqt5->labelImg) (12.9.0)
#
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\hp\anaconda3\lib\site-packages (from pyqt5->labelImg) (5.15.2)
#
# ```

# %% [markdown]
# ##소스 수정

# %% [markdown]
# ```
# canvas.py의 위치 - 소스의 위치가 달라질 수 있음 - log 파일에 있는 패스를 주의 깊게 보아야 함
#
#  ../anaconda3/Lib/site-pakages/libs    #일반적으로 user/PC명에 아나콘다가 설치됨
# ```
#
# ```
# canvas.py 526 line 변경
#
#             # p.drawRect(left_top.x(), left_top.y(), rect_width, rect_height)
#
#             p.drawRect(int(left_top.x()), int(left_top.y()), int(rect_width), int(rect_height))
# ```
#
# ```
# canvas.py 531 line 주석부문을 아래의 2 두라인으로 변경
#
#         if self.drawing() and not self.prev_point.isNull() and not self.out_of_pixmap(self.prev_point):
#
#             p.setPen(QColor(0, 0, 0))
#
#             # p.drawLine(self.prev_point.x(), 0, self.prev_point.x(), self.pixmap.height())
#
#             # p.drawLine(0, self.prev_point.y(), self.pixmap.width(), self.prev_point.y())
#
#             p.drawLine(int(self.prev_point.x()), 0, int(self.prev_point.x()), int(self.pixmap.height()))
#
#             p.drawLine(0, int(self.prev_point.y()), int(self.pixmap.width()), int(self.prev_point.y()))
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 실행

# %% [markdown]
# **(base) C:\Users\HP\anaconda3\Lib\site-packages\libs>labelImg**
